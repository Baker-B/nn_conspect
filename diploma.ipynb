# %% [markdown]
# ### Step 3.2 — Calculating gradients via Backpropagation
#
# Now, the question is how to update weights and biases.
#
# For example, take weight w3₁₁
# If we can calculate

# %%
# %%latex
#
# \begin{gather*}
#
# \end{gather*}
# Out:
# \begin{gather*}
#
# \end{gather*}

# %% [markdown]
# Аналіз сучасних методів визначення fingerprint
#
# Визначення проблем і недоліків існуючих рішень
#
# Формулювання гіпотез
#
# Визначення якісних критеріїв методу
#
# Визначити тип нейронної мережі
#
# Провести порівняльні тести архітектур нейронних мереж
#
# Чи визначено тип нейронної мережи?
#
# Розробити схему методу ідентифікації користувача
#
# Реалізувати розроблену схему програмно
#
# Визначити план експерименту для оцінки критеріїв методу
#
# Провести експеримент
#
# Чи дотримано якісних критеріїв методу?
#
# Провести аналіз результатів

# %% [markdown]
# 1. **Аналіз сучасних методів визначення fingerprint**: Проводиться ретельний огляд та аналіз сучасних методів ідентифікації fingerprint, які включають в себе як традиційні підходи, так і нові технології.
#
# 2. **Визначення проблем і недоліків існуючих рішень**: На основі аналізу існуючих методів визначення fingerprint визначаються їх слабкі місця та недоліки, які потребують подальшого вдосконалення.
#
# 3. **Формулювання гіпотез**: На основі аналізу слабких місць, проблем та недоліків попередніх рішень формулюються гіпотези щодо створення нового методу визначення fingerprint, який може вирішити існуючі проблеми.
#
# 4. **Визначення якісних критеріїв методу**: Визначаються об'єктивні критерії, які дозволять оцінити якість та ефективність нового методу.
#
# 5. **Визначити тип нейронної мережі**: Визначається конкретний тип нейронної мережі, яка буде використовуватися для ідентифікації користувачів, враховуючи специфіку задачі та вимоги до об'єктивних критеріїв оцінки методу.
#
# 6. **Провести порівняльні тести архітектур нейронних мереж**: Виконуються тести для вибору оптимальної архітектури нейронної мережі, яка найкраще відповідає завданню.
#
# 7. **Чи визначено тип нейронної мережи?**: перевіряється, чи було визначено найбільш ефективний  тип нейронної мережі для подальшого використання у методі.
#
# 8. **Розробити схему методу ідентифікації користувача**: Розробляється детальна схема методу ідентифікації користувача на основі обраної нейронної мережі.
#
# 9. **Реалізувати розроблену схему програмно**: Розроблена схема реалізується у вигляді програмного забезпечення для ідентифікації користувачів.
#
# 10. **Визначити план експерименту для оцінки критеріїв методу**: творюється план експерименту, який включає в себе процедури тестування та оцінки методу на підставі визначених якісних критеріїв.
#
# 11. **Провести експеримент**: За планом проводиться експеримент з використанням розробленого методу для ідентифікації користувачів.
#
# 12. **Чи дотримано якісних критеріїв методу?**: Перевіряється, чи метод відповідає визначеним якісним критеріям, і чи досягнуті поставлені цілі.
#
# 13. **Провести аналіз результатів**: Проводиться аналіз результатів експерименту з метою визначення ефективності методу для ідентифікації користувачів.
